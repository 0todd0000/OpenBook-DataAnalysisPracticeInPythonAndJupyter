# %% [markdown]
# # <span style="color:#1B3EA9">Jupyter Notebook:</span> &nbsp; File Operations
#
# <br>

# %% [markdown]
# <a name="toc"></a>
# # Table of Contents
#
# * [New](#create)
# * [Open](#open)
# * [Rename](#rename)
# * [Save](#save)
# * [Find notebook file on your PC](#find)
# * [Export](#export)
# * [Close](#close)
# * [Quit](#quit)
#
# <br>
# <br>

# %% [markdown]
# ___
#
# <a name="create"></a>
# # New
# [Back to Table of Contents](#toc)
# <br>
# <br>
#
# * Install and launch Jupyter as described in the [Install Jupyter](https://github.com/0todd0000/OpenBook-DataAnalysisPracticeInPythonAndJupyter/blob/master/Lessons/Lesson01/2-InstallJupyter/InstallJupyter.ipynb) notebook.
#
# * Select **New** , then **Python 3**
#
# <img src="img/ss0.png" alt="screenshot" width=600/>
#
# <br>
# <br>
#
# * A new notebook will be created in a new browser tab.
#
# <img src="img/ss1.png" alt="screenshot" width=600/>
#
# <br>
# <br>

# %% [markdown]
# ____
#
# <a name="open"></a>
# # Open
# [Back to Table of Contents](#toc)
# <br>
# <br>
#
# * From Jupyter's Home screen, click on the **.ipynb** file you want to open.
#
# <img src="img/ss12.png" alt="screenshot" width=600/>
#
# <br>
# <br>

# %% [markdown]
# ____
#
# <a name="rename"></a>
# # Rename
# [Back to Table of Contents](#toc)
# <br>
# <br>
#
# * By default, the Jupyter notebook is named **Untitled**
#
# * To rename the notebook, click on the file name.
#
#
#
#
# <img src="img/ss2.png" alt="screenshot" width=600/>
#
# <br>
# <br>
#
# * Enter a new file name in the dialog box, then press **Rename**.
#
# <img src="img/ss3.png" alt="screenshot" width=600/>
#
#
# <br>
# <br>
#
# * Return to the Jupyter Home Page (in the first tab), and verify that the file name has been saved.
#
# <img src="img/ss4.png" alt="screenshot" width=600/>
#
# <br>
# <br>

# %% [markdown]
# ____
#
# <a name="save"></a>
# # Save
# [Back to Table of Contents](#toc)
# <br>
# <br>
#
# * By default, Jupyter automatically saves notebook changes.
#
# * However, it is also useful to manually save the notebook when you reach milestones. For example: question finished, cell finished, assignment finished, etc.
#
# * To manually save the notebook, select **File** .. **Save and Checkpoint**
#
#
#
#
# <img src="img/ss8.png" alt="ascreenshot" width=600/>
#
# <br>
# <br>

# %% [markdown]
# ___
#
# <a name="find"></a>
# # Find notebook file on your PC
# [Back to Table of Contents](#toc)
# <br>
# <br>
#
#
#
# * When a notebook is created, it is saved to your computer as an **IPYNB** file (**I**nteractive **Py**thon **N**ote**b**ook)
#
# * To find out where on your PC a notebook is saved:
#     * Ensure that a notebook is open
#     * In a Python cell, enter `pwd` (print working directory) then select **Run**
#
# <img src="img/ss5.png" alt="screenshot" width=600/>
#
#
# <br>
# <br>
#
# * The **folder** containing the notebook will be displayed. In this case, it is the **Downloads** folder.
#
# <img src="img/ss6.png" alt="screenshot" width=600/>
#
#
# <br>
# <br>
#
# * Open a file explorer window (e.g., Explorer [Windows], Finder [Mac]) and find the folder.
#
# * Note that there is a file called **Assn01.ipynb** ; this is the notebook file.
#
# <img src="img/ss7.png" alt="screenshot" width=600/>

# %% [markdown]
# ____
#
# <a name="close"></a>
# # Close
# [Back to Table of Contents](#toc)
# <br>
# <br>
#
# * To close an open notebook, select **File** .. **Close and Halt**
#
#
# <img src="img/ss9.png" alt="ascreenshot" width=600/>
#
# <br>
# <br>
#
#
#
#
# * The tab will close, returning you to the Jupyter Home tab.
#
# * Verify that the notebook's icon is gray.
#
# * Also verify **Last Modified** time (i.e., the time when the notebook was last saved).
#
#
# <img src="img/ss10.png" alt="ascreenshot" width=600/>
#
# <br>
# <br>
#
#
#
# * Note that open notebooks' icons are green.
#
# * Also note that *Running* is displayed when the notebook is open.
#
#
# <img src="img/ss11.png" alt="ascreenshot" width=600/>
#
# <br>
# <br>

# %% [markdown]
# ____
#
# <a name="export"></a>
# # Export (HTML)
# [Back to Table of Contents](#toc)
# <br>
# <br>
#
#
# * Select **File** .. **Download as** .. **HTML**
#
#
# <img src="img/export-1.png" alt="ascreenshot" width=600/>
#
# <br>
# <br>
#
#
# * The exported HTML file will appear in the same folder as the open notebook.
#
# <img src="img/export-2.png" alt="ascreenshot" width=600/>
#
# <br>
# <br>
#
#
# * Double-click on the HTML file to open it.
#
# * Verify that the contents look as expected.
#
# <img src="img/export-3.png" alt="ascreenshot" width=600/>
#
#
#
# <br>
# <br>

# %% [markdown]
# ____
#
# <a name="quit"></a>
# # Quit
# [Back to Table of Contents](#toc)
# <br>
# <br>
#
# * Close all files as [described above](#close)
#
# * From the Jupyter Home screen, select **Quit**
#
# <img src="img/quit-1.png" alt="screenshot" width=600/>
#
# * Verify that the **Server stopped** message appears.
#
# <br>
# <br>
#
#
#
#
# <img src="img/quit-2.png" alt="screenshot" width=600/>
#
# <br>
# <br>
#
# * You can now safely close the brower tab and/or quit the browser.
#
# <br>
# <br>
